# %%
import csv
import matplotlib.pyplot as plt

dataVal={}
minSize=55
maxSize=55
window0=[-1]*minSize
window1=[-1]*maxSize
window2=[-1]*minSize*2
avg0=[]
avg1=[]
avg2=[]
output=[]
firstOne=5000
nullHigh=0
firstOneBool1=False
firstOneBool2=False
bitVal=-1
currentLevel=10000

with open('11001.rtf') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            line_count += 1
            if line_count<=86:
                continue
#             print(row)
            #print(f'{row[0]}+{row[1][:-1]}')
            dataVal[row[0]]=row[1][:-1]
            time=int(row[0])
            val=int(row[1][:-1])
            

#             window0=[val]+window0[0:-1]
#             avg0.append(sum(window0)/minSize)
            # print(window)
            window1=[val]+window1[0:-1]
            avg1.append(sum(window1)/maxSize)

#             if (avg1[-1]<850 and avg1[-1]>800):
#                 output.append(900)
#             elif (avg1[-1]<745 and avg1[-1]>700):
#                 output.append(800)
#             else:
#                 output.append(700)
            
            if avg1[-1]>nullHigh:
                nullHigh=avg1[-1]
#                 print(nullHigh)
############################################# Highlights region of interest
            if (abs(avg1[-1]-nullHigh)>100):
#                 output.append(700)
                firstOneBool1=True
                if not(firstOneBool2):
                    if avg1[-1]<firstOne:
                        firstOne=avg1[-1] ######## Picks out the value of first one. Need to reset after each packet
                        avg0.append(firstOne)
    #                   print(nullHigh)

            else:
                avg0.append(firstOne)
#                 output.append(900)
                if firstOneBool1:
                    firstOneBool2=True
#                 firstOne=nullHigh

############################################### 
            if (abs(avg1[-1]-nullHigh)>100): #### This 100 should be dynamic
                if avg1[-1]<currentLevel:
                    currentLevel=avg1[-1]
            else:
                currentLevel=nullHigh
                


            if currentLevel>firstOne and abs(currentLevel-firstOne)<100:
                bitVal=600
            elif currentLevel<firstOne and abs(currentLevel-firstOne)<100:
                bitVal=800
            else:
                bitVal=700
                
            window0=[bitVal]+window0[0:-1]
            output.append(sum(window0)/minSize)
#             output.append(bitVal)
#             output.append(currentLevel)
#             avg2.append(firstOne)
            

    print(f'Processed {line_count} lines.')
    # print(dataVal)
    plt.figure(figsize=(20, 5))
    plt.plot(list(dataVal.keys())[2000:5000],avg0[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg1[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],output[2000:5000])
    plt.show()
# Out:
# Processed 15654 lines.

# %%
import csv
import matplotlib.pyplot as plt

dataVal={}
minSize=55
maxSize=55
window0=[-1]*minSize
window1=[-1]*maxSize
window2=[-1]*minSize*2
avg0=[]
avg1=[]
avg2=[]
output=[]
firstOne=5000
nullHigh=0
firstOneBool1=False
firstOneBool2=False
bitVal=-1
currentLevel=10000

with open('11001.rtf') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            line_count += 1
            if line_count<=86:
                continue
#             print(row)
            #print(f'{row[0]}+{row[1][:-1]}')
            dataVal[row[0]]=row[1][:-1]
            time=int(row[0])
            val=int(row[1][:-1])
            
            window1=[val]+window1[0:-1]
            avg1.append(sum(window1)/maxSize)

            avg0.append(nullHigh)
            if avg1[-1]>nullHigh:
                nullHigh=avg1[-1]
                
            if (abs(avg1[-1]-nullHigh)>100):
                if avg1[-1]<firstOne:
                    firstOne=avg1[-1] ######## Picks out the value of first one. Need to reset after each packet
            else:
                firstOne=nullHigh
            avg2.append(firstOne)
            

    print(f'Processed {line_count} lines.')
    # print(dataVal)
    plt.figure(figsize=(20, 5))
    plt.plot(list(dataVal.keys())[2000:5000],avg0[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg1[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg2[2000:5000])
#     plt.plot(list(dataVal.keys())[2000:5000],output[2000:5000])
    plt.show()
# Out:
# Processed 15654 lines.

# %%
import csv
import matplotlib.pyplot as plt

dataVal={}
minSize=55
maxSize=55
window0=[-1]*minSize
window1=[-1]*maxSize
window2=[-1]*minSize*2
avg0=[]
avg1=[]
avg2=[]
avg3=[]
output=[]
firstOne=5000
nullHigh=0
firstOneBool1=False
firstOneBool2=False
bitVal=-1
currentLevel=10000
packetTimeout=0
packetEnd=300
packetEndPrev=300
with open('11001.rtf') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            line_count += 1
            if line_count<=86:
                continue
#             print(row)
            #print(f'{row[0]}+{row[1][:-1]}')
            dataVal[row[0]]=row[1][:-1]
            time=int(row[0])
            val=int(row[1][:-1])
            
            
            
            
            
            window1=[val]+window1[0:-1]
            avg1.append(sum(window1)/maxSize)

            
            
            
            
            if (abs(avg1[-1]-nullHigh)>100):
                packetTimeout=0
            if firstOne==nullHigh:
                packetTimeout+=1
            if packetTimeout>100:
                packetEnd=500
            else:
                packetEnd=300
            if packetEndPrev!=packetEnd:
                print("New Packet")
            packetEndPrev=packetEnd
            avg3.append(packetEnd)
            
            
            
            
            
            avg0.append(nullHigh)
            if avg1[-1]>nullHigh:
                nullHigh=avg1[-1]
                
            if (abs(avg1[-1]-nullHigh)>100):
                if avg1[-1]<firstOne:
                    firstOne=avg1[-1] ######## Picks out the value of first one. Need to reset after each packet
            else:
                firstOne=nullHigh    
            avg2.append(firstOne)
            
            
            

    print(f'Processed {line_count} lines.')
    # print(dataVal)
    plt.figure(figsize=(20, 5))
#     plt.plot(list(dataVal.keys())[2000:5000],avg0[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg1[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg2[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg3[2000:5000])
#     plt.plot(list(dataVal.keys())[2000:5000],output[2000:5000])
    plt.show()
# Out:
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# Processed 15654 lines.

# %%
import csv
import matplotlib.pyplot as plt

dataVal={}
minSize=55
maxSize=55
window0=[-1]*minSize
window1=[-1]*maxSize
window2=[-1]*minSize*2
avg0=[]
avg1=[]
avg2=[]
avg3=[]
output=[]
firstOne=5000
startBit=5000
nullHigh=0
firstOneBool1=False
firstOneBool2=False
bitVal=-1
currentLevel=10000
packetTimeout=0
packetEnd=300
packetEndPrev=300
with open('11001.rtf') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            line_count += 1
            if line_count<=86:
                continue
#             print(row)
            #print(f'{row[0]}+{row[1][:-1]}')
            dataVal[row[0]]=row[1][:-1]
            time=int(row[0])
            val=int(row[1][:-1])
            
            
            
            
            
            window1=[val]+window1[0:-1]
            avg1.append(sum(window1)/maxSize)

            
            
            
            
            if (abs(avg1[-1]-nullHigh)>100):
                packetTimeout=0
            if firstOne==nullHigh:
                packetTimeout+=1
            if packetTimeout>100:
                packetEnd=500
            else:
                packetEnd=300
            if packetEndPrev!=packetEnd:
                print("New Packet")
                firstOneBool1=False
                firstOneBool2=False
                startBit=1000
                
            packetEndPrev=packetEnd
            avg3.append(packetEnd)
            
            
            
            
            
            avg0.append(nullHigh)
            if avg1[-1]>nullHigh:
                nullHigh=avg1[-1]     
                
            if (abs(avg1[-1]-nullHigh)>100):
                if avg1[-1]<firstOne:
                    firstOne=avg1[-1] ######## Picks out the value of first one. Need to reset after each packet
            else:
                firstOne=nullHigh    
            #avg2.append(firstOne)
            
            if (abs(avg1[-1]-nullHigh)>100):
                firstOneBool1=True
                if not(firstOneBool2):
                    if avg1[-1]<startBit:
                        startBit=avg1[-1] ######## Picks out the value of first one. Need to reset after each packet
            else:
                if firstOneBool1:
                    firstOneBool2=True
                #firstOne=nullHigh
            avg2.append(startBit)
            
            
            

    print(f'Processed {line_count} lines.')
    # print(dataVal)
    plt.figure(figsize=(20, 5))
#     plt.plot(list(dataVal.keys())[2000:5000],avg0[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg1[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg2[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg3[2000:5000])
#     plt.plot(list(dataVal.keys())[2000:5000],output[2000:5000])
    plt.show()
# Out:
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# New Packet
# Processed 15654 lines.

# %%
import csv
import matplotlib.pyplot as plt

dataVal={}
minSize=55
maxSize=55
window0=[-1]*minSize
window1=[-1]*maxSize
window2=[-1]*minSize*2
avg0=[]
avg1=[]
avg2=[]
avg3=[]
avg4=[]
output=[]
firstOne=5000
startBit=5000
nullHigh=0
firstOneBool1=False
firstOneBool2=False
bitVal=-1
currentLevel=10000
packetTimeout=0
packetEnd=300
packetEndPrev=300
with open('11001.rtf') as csv_file:
    csv_reader = csv.reader(csv_file, delimiter=',')
    line_count = 0
    for row in csv_reader:
            line_count += 1
            if line_count<=86:
                continue
#             print(row)
            #print(f'{row[0]}+{row[1][:-1]}')
            dataVal[row[0]]=row[1][:-1]
            time=int(row[0])
            val=int(row[1][:-1])
            
            
            
            
            
            window1=[val]+window1[0:-1]
            avg1.append(sum(window1)/maxSize)

            
            
            
            
            if (abs(avg1[-1]-nullHigh)>100):
                packetTimeout=0
            if firstOne==nullHigh:
                packetTimeout+=1
            if packetTimeout>100:
                packetEnd=500
            else:
                packetEnd=300
            if packetEndPrev!=packetEnd:
                #print("New Packet")
                firstOneBool1=False
                firstOneBool2=False
                startBit=1000
                
            packetEndPrev=packetEnd
            avg3.append(packetEnd)
            
            
            
            
            
            avg0.append(nullHigh)
            if avg1[-1]>nullHigh:
                nullHigh=avg1[-1]     
                
            if (abs(avg1[-1]-nullHigh)>100):
                if avg1[-1]<firstOne:
                    firstOne=avg1[-1] ######## Picks out the value of first one. Need to reset after each packet
            else:
                firstOne=nullHigh    
            avg4.append(firstOne)
            
            
            
            
            
            if (abs(avg1[-1]-nullHigh)>100):
                firstOneBool1=True
                if not(firstOneBool2):
                    if avg1[-1]<startBit:
                        startBit=avg1[-1] ######## Picks out the value of first one. Need to reset after each packet
            else:
                if firstOneBool1:
                    firstOneBool2=True
                #firstOne=nullHigh
            avg2.append(startBit)
            
            
            
            
            if packetEnd==300:
                if firstOne>startBit and abs(nullHigh-firstOne)>100:
                    bitVal=800
                elif firstOne<=startBit and abs(nullHigh-firstOne)>100:
                    bitVal=600
                else:
                    bitVal=700

            window0=[bitVal]+window0[0:-1]
            output.append(sum(window0)/minSize)
            #output.append(bitVal)
            
            
            

    print(f'Processed {line_count} lines.')
    # print(dataVal)
    plt.figure(figsize=(20, 5))
#     plt.plot(list(dataVal.keys())[2000:5000],avg0[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg1[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg2[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg3[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],avg4[2000:5000])
    plt.plot(list(dataVal.keys())[2000:5000],output[2000:5000])
    plt.show()
# Out:
# Processed 15654 lines.
